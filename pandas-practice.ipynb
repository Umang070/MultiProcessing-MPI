# %%
import pandas as pd

# %%
fields = ['Airline','Month','Year','Cancelled']
df = pd.read_csv('./datasets/Combined_Flights_2021.csv',usecols=[1,4,16,18],header=None,skiprows=1)
df.head()
# Out:
#                       1      4     16  18
# 0  SkyWest Airlines Inc.  False  2021   3
# 1  SkyWest Airlines Inc.  False  2021   3
# 2  SkyWest Airlines Inc.  False  2021   3
# 3  SkyWest Airlines Inc.  False  2021   3
# 4  SkyWest Airlines Inc.  False  2021   3

# %%
df[(df.iloc[:,1] == True) & (df.iloc[:,2] == 2021) & (df.iloc[:,3] == 9) ].iloc[:,0].value_counts()
# Out:
# Southwest Airlines Co.                       2326
# American Airlines Inc.                        759
# Republic Airlines                             704
# United Air Lines Inc.                         633
# JetBlue Airways                               487
# GoJet Airlines, LLC d/b/a United Express      428
# Spirit Air Lines                              316
# SkyWest Airlines Inc.                         297
# Delta Air Lines Inc.                          295
# Air Wisconsin Airlines Corp                   286
# Comair Inc.                                   202
# Commutair Aka Champlain Enterprises, Inc.     202
# Mesa Airlines Inc.                            160
# Envoy Air                                     135
# Capital Cargo International                   132
# Alaska Airlines Inc.                          127
# Endeavor Air Inc.                              80
# Frontier Airlines Inc.                         79
# Allegiant Air                                  50
# ...

# %%
df1 = pd.read_csv('./datasets/Combined_Flights_2021.csv', skiprows=1, header=None, usecols=[12,34,42])

# %%
df1.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
#question 2
df1[((df1.iloc[:,0] == False) & (df1.iloc[:,1]==3) & ((df1.iloc[:,2] >= 3) & (df1.iloc[:,2] <=30))) ].iloc[:,0].count()
# Out:
# 50

# %%
#question 3
df1[(df1.iloc[:,1] == 'Nashville, TN') & (df1.iloc[:,2] == 'Chicago, IL')].iloc[:,0].mean()
# BNA ORD
# Out:
# 72.73409801876956

# %%
df1.head()
# Out:
#       12  35                                  42
# 0   49.0  UT                         Phoenix, AZ
# 1   48.0  AZ                      St. George, UT
# 2  129.0  NH                         Chicago, IL
# 3  112.0  TX  Bristol/Johnson City/Kingsport, TN
# 4   69.0  AZ                     Bakersfield, CA

# %%
df2 = pd.read_csv('./datasets/Combined_Flights_2021.csv',skiprows=1,header=None,usecols=[0,7])

# %%
df2[(df2.iloc[:,1].isna() == True)].iloc[:,0].tolist()
# Out:
# ['2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-25',
#  '2021-03-05',
#  '2021-03-05',
#  '2021-03-05',
#  '2021-03-05',
#  '2021-03-06',
#  '2021-03-06',
#  '2021-03-06',
#  '2021-03-06',
#  '2021-03-06',
#  '2021-03-06',
#  '2021-03-23',
#  '2021-03-24',
#  '2021-03-13',
#  '2021-03-14',
#  '2021-03-14',
#  '2021-03-15',
#  '2021-03-15',
#  '2021-03-13',
#  '2021-03-14',
#  '2021-03-14',
#  '2021-03-14',
#  '2021-03-15',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-13',
#  '2021-03-13',
#  '2021-03-14',
#  '2021-03-14',
#  '2021-03-15',
#  '2021-03-15',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-18',
#  '2021-03-04',
# ...

# %%
df2.head()
# Out:
#             0       7
# 0  2021-03-03   714.0
# 1  2021-03-03   917.0
# 2  2021-03-03  1321.0
# 3  2021-03-03  1636.0
# 4  2021-03-03  1838.0
